# %%
import pandas as pd

# %%
train = pd.read_csv('train.csv')

# %%
shape(train)
# Out:
# (891, 12)

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
train[0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
train.iloc[[0]]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex  Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male   22      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S
#
# [1 rows x 12 columns]

# %%
# converting it to 2-D matrix
#train_matrix = train.as_matrix()

# %%
# shape(train_matrix)

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)

# %%
train.Cabin[0:10]
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# 6     E46
# 7     NaN
# 8     NaN
# 9     NaN
# Name: Cabin, dtype: object

# %%
train.Age.median()
# Out:
# 28.0

# %%
train[['Age', 'Pclass', 'Age']][0:5]
# Out:
#    Age  Pclass  Age
# 0   22       3   22
# 1   38       1   38
# 2   26       3   26
# 3   35       1   35
# 4   35       3   35
#
# [5 rows x 3 columns]

# %%
train[train['Age'] > 60]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
train[train['Age'] > 60][['Sex', 'Pclass', 'Age','Survived']]
# Out:
#         Sex  Pclass   Age  Survived
# 33     male       2  66.0         0
# 54     male       1  65.0         0
# 96     male       1  71.0         0
# 116    male       3  70.5         0
# 170    male       1  61.0         0
# 252    male       1  62.0         0
# 275  female       1  63.0         1
# 280    male       3  65.0         0
# 326    male       3  61.0         0
# 438    male       1  64.0         0
# 456    male       1  65.0         0
# 483  female       3  63.0         1
# 493    male       1  71.0         0
# 545    male       1  64.0         0
# 555    male       1  62.0         0
# 570    male       2  62.0         1
# 625    male       1  61.0         0
# 630    male       1  80.0         1
# 672    male       2  70.0         0
# 745    male       1  70.0         0
# 829  female       1  62.0         1
# 851    male       3  74.0         0
#
# [22 rows x 4 columns]

# %%
train[train['Age'].isnull()][['Sex', 'Pclass', 'Age','Survived']]
# Out:
#         Sex  Pclass  Age  Survived
# 5      male       3  NaN         0
# 17     male       2  NaN         1
# 19   female       3  NaN         1
# 26     male       3  NaN         0
# 28   female       3  NaN         1
# 29     male       3  NaN         0
# 31   female       1  NaN         1
# 32   female       3  NaN         1
# 36     male       3  NaN         1
# 42     male       3  NaN         0
# 45     male       3  NaN         0
# 46     male       3  NaN         0
# 47   female       3  NaN         1
# 48     male       3  NaN         0
# 55     male       1  NaN         1
# 64     male       1  NaN         0
# 65     male       3  NaN         1
# 76     male       3  NaN         0
# 77     male       3  NaN         0
# 82   female       3  NaN         1
# 87     male       3  NaN         0
# 95     male       3  NaN         0
# 101    male       3  NaN         0
# 107    male       3  NaN         1
# 109  female       3  NaN         1
# 121    male       3  NaN         0
# ...

# %%
train.groupby(['Pclass', 'Sex']).size()
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# dtype: int64

# %%
train.Age.hist()

# %%
train.Age.dropna().hist(bins=16, range=(0,80), alpha=.5)

# %%
train['Gender'] = train.Sex.map(lambda x: x[0].upper())

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked Gender
# 0      0         A/5 21171   7.2500   NaN        S      M
# 1      0          PC 17599  71.2833   C85        C      F
# 2      0  STON/O2. 3101282   7.9250   NaN        S      F
# 3      0            113803  53.1000  C123        S      F
# ...

# %%
train['Gender'] = train.Sex.map( {'female': 0, 'male': 1}).astype(int)

# %%
train.groupby('Embarked').size()
# Out:
# Embarked
# C           168
# Q            77
# S           644
# dtype: int64

# %%
train['EmbarkedInt'] = train.Embarked.dropna().map({'C': 0, 'S': 1, 'Q': 2}).astype(int)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender  AgeFill  \
# 0      0         A/5 21171   7.2500   NaN        S       1       22
# 1      0          PC 17599  71.2833   C85        C       0       38
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0       26
# ...

# %% [markdown]
# ### Tried to find standard deviation with easy method
# $$ \sigma = \sqrt((\sum{x^2})/n - \mu^2) $$

# %%
a = np.arange(1, 8)

# %%
np.std(a)
# Out:
# 2.0

# %%
sqrt((np.sum(a ** 2) / float(len(a))) / np.mean(a) ** 2)
# Out:
# 1.1180339887498949

# %%
sqrt((np.sum(train.Age ** 2) / float(len(train.Age.dropna()))) - np.mean(train.Age) ** 2)
# Out:
# 14.516321150817321

# %%
np.std(train.Age)
# Out:
# 14.516321150817312

# %%
a = np.array([7, 9, 9, 10, 10, 10, 10, 11, 11, 13])

# %%
sqrt((np.sum(a ** 2) / float(len(a))) - np.mean(a) ** 2)
# Out:
# 1.4832396974191335

# %%
np.std(a)
# Out:
# 1.4832396974191326

# %%
train['AgeFill'] = train['Age']

# %%
train[train['Age'].isnull()][['Gender', 'Pclass', 'Age', 'AgeFill']].head(10)
# Out:
#     Gender  Pclass  Age  AgeFill
# 5        1       3  NaN      NaN
# 17       1       2  NaN      NaN
# 19       0       3  NaN      NaN
# 26       1       3  NaN      NaN
# 28       0       3  NaN      NaN
# 29       1       3  NaN      NaN
# 31       0       1  NaN      NaN
# 32       0       3  NaN      NaN
# 36       1       3  NaN      NaN
# 42       1       3  NaN      NaN
#
# [10 rows x 4 columns]

# %%
median_age = train.groupby(['Pclass', 'Sex']).median()['Age']
median_age
# Out:
# Pclass  Sex
# 1       female    35.0
#         male      40.0
# 2       female    28.0
#         male      30.0
# 3       female    21.5
#         male      25.0
# Name: Age, dtype: float64

# %%
median_age_array = np.reshape(median_age, (2, 3), order='F') # Fortran like index ordering
median_age_array
# Out:
# array([[ 35. ,  28. ,  21.5],
#        [ 40. ,  30. ,  25. ]])

# %%
for i in range(0, 2):
    for j in range(0, 3):
        train.loc[train.Age.isnull() & (train.Gender == i) & (train.Pclass == j+1), 'AgeFill'] = median_age_array[i, j]

# %%
train[train['Age'].isnull()][['Gender', 'Pclass', 'Age', 'AgeFill']].head(10)
# Out:
#     Gender  Pclass  Age  AgeFill
# 5        1       3  NaN     25.0
# 17       1       2  NaN     30.0
# 19       0       3  NaN     21.5
# 26       1       3  NaN     25.0
# 28       0       3  NaN     21.5
# 29       1       3  NaN     25.0
# 31       0       1  NaN     35.0
# 32       0       3  NaN     21.5
# 36       1       3  NaN     25.0
# 42       1       3  NaN     25.0
#
# [10 rows x 4 columns]

# %%
median_age_group = train.groupby(['Pclass', 'Sex'])

# %%
median_age_group.indices.keys()
# Out:
# [(1, 'female'),
#  (3, 'female'),
#  (1, 'male'),
#  (2, 'female'),
#  (2, 'male'),
#  (3, 'male')]

# %%
median_age_group.indices.values()[0]
# Out:
# array([  1,   3,  11,  31,  52,  61,  88, 136, 151, 166, 177, 194, 195,
#        215, 218, 230, 256, 257, 258, 268, 269, 275, 290, 291, 297, 299,
#        306, 307, 309, 310, 311, 318, 319, 325, 329, 334, 337, 341, 356,
#        366, 369, 375, 380, 383, 393, 412, 435, 457, 486, 496, 498, 504,
#        513, 520, 523, 537, 539, 540, 556, 558, 571, 577, 581, 585, 591,
#        609, 627, 641, 669, 689, 700, 708, 710, 716, 730, 742, 759, 763,
#        765, 779, 781, 796, 809, 820, 829, 835, 842, 849, 853, 856, 862,
#        871, 879, 887], dtype=int64)

# %%
median_age[median_age_group.indices.keys()]
# Out:
# Pclass  Sex
# 1       female    35.0
# 3       female    21.5
# 1       male      40.0
# 2       female    28.0
#         male      30.0
# 3       male      25.0
# Name: Age, dtype: float64

# %%
#train.iloc[median_age_group.indices.values()]
type(median_age_group.indices)
# Out:
# dict

# %%
for class_key in median_age_group.indices.keys():
    pass
    # print type(median_age_group.indices[class_key])
    # print median_age[class_key]
    # index = df['b'].index[df['b'].apply(np.isnan)]
    # print len(train.iloc[train.Age.isnull().index[median_age_group.indices[class_key]]])
    # print train.iloc[median_age_group.indices[class_key]]['Age'].isnull()
    # print len(train.iloc[median_age_group.indices[class_key]]['Age'].dropna())
    # print train.index[nulls.index]
    # print len(train.iloc[median_age_group.indices[class_key]]['Age'])
    # print len(train.ix(train.Age.isnull() & median_age_group.indices, 'AgeFill'))
    # print train.iloc[median_age_group.indices[class_key]] # = median_age[class_key]

# %%
train['AgeIsNull'] = pd.isnull(train.Age).astype(int)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender  AgeFill  \
# 0      0         A/5 21171   7.2500   NaN        S       1       22
# 1      0          PC 17599  71.2833   C85        C       0       38
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0       26
# ...

# %%
train['FamilySize'] = train.Parch + train.SibSp

# %%
train.FamilySize.mean()
# Out:
# 0.90460157126823793

# %% [markdown]
# ### Tried gendermodel.py

# %%
women_on_board = train[train['Sex'] == "female"]
men_on_board = train[train['Sex'] == "male"]

# %%
print 'Women surived', len(women_on_board[women_on_board['Survived'] == 1])/float(len(women_on_board))
print 'Men survived', len(men_on_board[men_on_board['Survived'] == 1])/float(len(men_on_board))
# Out:
# Women surived 0.742038216561
# Men survived 0.188908145581

# %%
train['AgeClass'] = train.AgeFill * train.Pclass

# %%
train.AgeClass.hist(bins = 16)

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Gender           int32
# AgeFill        float64
# AgeIsNull        int32
# FamilySize       int64
# AgeClass       float64
# dtype: object

# %%
train.dtypes[train.dtypes.map(lambda x: x == 'object')]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
train_clean = train
train_clean = train_clean.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], axis=1)

# %%
train_clean = train_clean.drop(['Age'], axis=1)

# %%
train_clean.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# SibSp            int64
# Parch            int64
# Fare           float64
# Gender           int32
# AgeFill        float64
# AgeIsNull        int32
# FamilySize       int64
# AgeClass       float64
# EmbarkedInt    float64
# dtype: object

# %%
# convert it to numpy array
train_array = train_clean.values

# %%
shape(train_array)
# Out:
# (891, 12)
